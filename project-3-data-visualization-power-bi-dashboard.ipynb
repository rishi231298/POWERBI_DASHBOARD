# %% [markdown]
# **PLEASE DOWNLOAD POWER BI FILE**

# %% [markdown]
# **Daily Analysis**

# %% [markdown]
# ![image.png](attachment:b81a64e8-f9ea-401c-af65-f6223dafbc70.png)

# %% [markdown]
# **Monthly Analysis**

# %% [markdown]
# ![image.png](attachment:c4eaceec-168f-412a-8bc4-fd2ad45809e8.png)
